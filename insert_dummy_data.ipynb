# %% [markdown]
# # Queries to add dummy data

# %%
INSERT INTO countries (country_code, country_name, dialling_code) VALUES
('US', 'United States', 1),
('CA', 'Canada', 1),
('GB', 'United Kingdom', 44),
('AU', 'Australia', 61),
('NZ', 'New Zealand', 64),
('IN', 'India', 91),
('ZA', 'South Africa', 27),
('SG', 'Singapore', 65),
('FR', 'France', 33),
('DE', 'Germany', 49),
('BR', 'Brazil', 55),
('JP', 'Japan', 81),
('CN', 'China', 86),
('IT', 'Italy', 39),
('ES', 'Spain', 34),
('TH', 'Thailand', 66),
('MX', 'Mexico', 52),
('KE', 'Kenya', 254),
('NG', 'Nigeria', 234),
('EG', 'Egypt', 20),
('TR', 'Turkey', 90),
('RU', 'Russia', 7),
('NL', 'Netherlands', 31),
('BE', 'Belgium', 32),
('PL', 'Poland', 48),
('PH', 'Philippines', 63),
('MY', 'Malaysia', 60),
('SA', 'Saudi Arabia', 966),
('KR', 'South Korea', 82),
('SE', 'Sweden', 46),
('NO', 'Norway', 47),
('FI', 'Finland', 358),
('DK', 'Denmark', 45),
('IE', 'Ireland', 353),
('CH', 'Switzerland', 41),
('AT', 'Austria', 43),
('GR', 'Greece', 30),
('IL', 'Israel', 972),
('PT', 'Portugal', 351),
('AE', 'United Arab Emirates', 971),
('CO', 'Colombia', 57),
('AR', 'Argentina', 54),
('CL', 'Chile', 56),
('PE', 'Peru', 51),
('VE', 'Venezuela', 58),
('MA', 'Morocco', 212),
('UA', 'Ukraine', 380),
('CZ', 'Czech Republic', 420),
('HU', 'Hungary', 36),
('ID', 'Indonesia', 62),
('UK', 'United Kingdom', 44);

INSERT INTO currencies (currency_code, currency_name, exchange_rate) VALUES
('USD', 'US Dollar', 1.100000),
('GBP', 'British Pound', 0.850000),
('CAD', 'Canadian Dollar', 1.450000),
('AUD', 'Australian Dollar', 1.580000),
('NZD', 'New Zealand Dollar', 1.690000),
('INR', 'Indian Rupee', 79.250000),
('ZAR', 'South African Rand', 17.500000),
('SGD', 'Singapore Dollar', 1.520000),
('JPY', 'Japanese Yen', 130.000000),
('CNY', 'Chinese Yuan', 7.400000),
('CHF', 'Swiss Franc', 1.020000),
('NOK', 'Norwegian Krone', 9.800000),
('SEK', 'Swedish Krona', 10.300000),
('DKK', 'Danish Krone', 7.440000),
('RUB', 'Russian Ruble', 82.500000),
('BRL', 'Brazilian Real', 5.260000),
('MXN', 'Mexican Peso', 21.300000),
('KRW', 'South Korean Won', 1350.000000),
('TRY', 'Turkish Lira', 15.500000),
('HKD', 'Hong Kong Dollar', 8.650000),
('EUR', 'Euro', 1);

INSERT INTO property_types (type_name, description) VALUES
('Apartment', 'An individual unit in a multi-unit building.'),
('House', 'A single-family dwelling with no shared walls.'),
('Loft', 'A large, open space that can be used as a living area.'),
('Condominium', 'A private residence in a multi-unit complex with shared common areas.'),
('Townhouse', 'A multilevel home that shares one or more walls with other units.'),
('Bungalow', 'A small, single-story house with a front porch.'),
('Cottage', 'A small, cozy house typically found in a rural or semi-rural location.'),
('Villa', 'A large and luxurious country house in its own grounds.'),
('Chalet', 'A wooden house with overhanging eaves, typically found in the Swiss Alps.'),
('Cabin', 'A small rustic house typically made of wood and located in a rural area.'),
('Studio', 'A small apartment consisting of one main room.'),
('Farmhouse', 'A house attached to a farm, especially the main house.'),
('Serviced Apartment', 'An apartment with hotel-like amenities.'),
('Boat', 'A watercraft that has been modified for use as a living space.'),
('Mansion', 'A large, impressive house or estate.'),
('Castle', 'A large building typically of the medieval period, fortified against attack.'),
('Hostel', 'An establishment which provides inexpensive food and lodging for a specific group of people, such as students.'),
('Bed & Breakfast', 'A small lodging establishment that offers overnight accommodation and breakfast.'),
('Guesthouse', 'A private house offering accommodations to paying guests.'),
('Penthouse', 'An apartment on the top floor of a tall building, typically luxuriously fitted and offering fine views.');

INSERT INTO addresses (street_address, state, city, postcode, country) VALUES
('123 Main St', 'California', 'Los Angeles', '90001', 'US'),
('456 Elm St', 'New York', 'New York', '10001', 'US'),
('789 Pine St', 'Texas', 'Houston', '77001', 'US'),
('1011 Oak Rd', 'Florida', 'Miami', '33101', 'US'),
('1213 Cedar Blvd', 'Illinois', 'Chicago', '60007', 'US'),
('789 High St', 'England', 'London', 'SW1A 1AA', 'UK'),
('1012 Oak St', 'Scotland', 'Edinburgh', 'EH1 1RF', 'UK'),
('1314 Pine Dr', 'Wales', 'Cardiff', 'CF10 1BS', 'UK'),
('1516 Birch Ln', 'Northern Ireland', 'Belfast', 'BT1 5GS', 'UK'),
('1314 Maple Ave', 'Ontario', 'Toronto', 'M5H 2N2', 'CA'),
('1516 Pine St', 'British Columbia', 'Vancouver', 'V5K 0A1', 'CA'),
('1718 Spruce Way', 'Quebec', 'Montreal', 'H1A 0A1', 'CA'),
('1920 Willow Rd', 'Alberta', 'Calgary', 'T2P 1G1', 'CA'),
('1718 George St', 'New South Wales', 'Sydney', '2000', 'AU'),
('1920 King St', 'Victoria', 'Melbourne', '3000', 'AU'),
('2122 Queen Ave', 'Queensland', 'Brisbane', '4000', 'AU'),
('2324 Jack Blvd', 'Western Australia', 'Perth', '6000', 'AU'),
('2122 Cherry Blossom Lane', 'Tokyo', 'Shibuya', '150-0002', 'JP'),
('2324 Maple St', 'Kanagawa', 'Yokohama', '221-0835', 'JP'),
('2526 Oak Rd', 'Osaka', 'Osaka', '530-0001', 'JP'),
('2728 Cedar Ave', 'Aichi', 'Nagoya', '460-0008', 'JP'),
('2324 Long St', 'Gauteng', 'Johannesburg', '2000', 'ZA'),
('2526 Wide Ave', 'Western Cape', 'Cape Town', '8001', 'ZA'),
('2728 High Rd', 'KwaZulu-Natal', 'Durban', '4001', 'ZA'),
('2930 Big Blvd', 'Eastern Cape', 'Port Elizabeth', '6001', 'ZA'),
('2526 Hauptstrasse', 'Bavaria', 'Munich', '80331', 'DE'),
('2728 Lindenweg', 'Berlin', 'Berlin', '10115', 'DE'),
('2930 Kastanienallee', 'North Rhine-Westphalia', 'Cologne', '50667', 'DE'),
('3132 Goethestrasse', 'Hesse', 'Frankfurt', '60313', 'DE'),
('2728 Rue de Rivoli', 'Île-de-France', 'Paris', '75001', 'FR'),
('2930 Rue St. Antoine', 'Provence-Alpes-Côte d\'Azur', 'Marseille', '13001', 'FR'),
('3132 Rue des Moulins', 'Auvergne-Rhône-Alpes', 'Lyon', '69002', 'FR'),
('3334 Rue Vaugirard', 'Nouvelle-Aquitaine', 'Bordeaux', '33000', 'FR'),
('2930 Bøgevej', 'Capital Region', 'Copenhagen', '1050', 'DK'),
('3132 Fyrrevej', 'Central Denmark', 'Aarhus', '8000', 'DK'),
('3334 Elmegade', 'Southern Denmark', 'Odense', '5000', 'DK'),
('3536 Strandvejen', 'North Denmark', 'Aalborg', '9000', 'DK');

INSERT INTO amenities (amenity_name, description) VALUES
('Wi-Fi', 'High-speed wireless internet access throughout the property.'),
('Air Conditioning', 'Central or individual air conditioning units available.'),
('Heating', 'Indoor heating available in all rooms.'),
('Kitchen', 'Fully equipped kitchen with appliances and utensils.'),
('Washer', 'In-unit washer for laundry.'),
('Dryer', 'In-unit dryer for laundry.'),
('TV', 'Television with cable/satellite access.'),
('Private Bathroom', 'A bathroom available for personal use.'),
('Pool', 'Access to a private or shared swimming pool.'),
('Parking', 'On-site parking available.'),
('Gym', 'Access to a fitness center or gym.'),
('Hot Tub', 'Hot tub available for relaxation and leisure.'),
('Balcony', 'Outdoor balcony with seating area.'),
('Pet Friendly', 'Accommodation suitable for pets.'),
('Smoke Alarms', 'Smoke alarms installed for safety.'),
('First Aid Kit', 'First aid kit available in the property.'),
('Fire Extinguisher', 'Fire extinguisher available in case of emergency.'),
('Essentials', 'Towels, bed sheets, soap, and toilet paper provided.'),
('Breakfast', 'Breakfast options available.'),
('24-Hour Check-in', 'Check-in available at any time after check-in hour.');

INSERT INTO house_rules (rule_name, description) VALUES
('No Smoking', 'Smoking is not allowed inside or around the property.'),
('No Pets', 'Pets are not allowed in the property at any time.'),
('No Parties', 'Parties and loud music are strictly prohibited.'),
('Quiet Hours', 'Please observe quiet hours from 10 PM to 7 AM.'),
('Maximum Occupancy', 'The maximum number of guests should not exceed 5.'),
('Check-in Time', 'Check-in is available from 3 PM to 9 PM.'),
('Check-out Time', 'Check-out must be completed by 11 AM on the departure day.'),
('Parking', 'Parking is available for one vehicle per reservation.'),
('Age Requirement', 'The primary renter must be at least 25 years old.'),
('Self-Catering', 'The property is self-catering, please maintain cleanliness.'),
('Recycling Rules', 'Please follow the recycling guidelines provided in the welcome manual.'),
('No Long-term Storage', 'Storage of personal goods beyond stay duration is not allowed.'),
('Energy Saving', 'Please turn off lights and appliances when not in use.'),
('Water Usage', 'Please conserve water by limiting shower time.'),
('Report Damages', 'Any damages to the property must be reported immediately.'),
('Use of Amenities', 'Use property amenities responsibly and adhere to guidelines.'),
('No Subletting', 'Subletting or re-rental of the property is strictly prohibited.'),
('Key Return', 'Please return all keys at the time of check-out.'),
('Emergency Procedures', 'Familiarize yourself with fire exits and emergency procedures.'),
('Security Cameras', 'Security cameras are installed in public areas for safety.');

INSERT INTO cancellation_policies (policy_name, description, time_frame, refund_percentage) VALUES
('Flexible', 'Full refund 1 day prior to arrival, except fees.', 1, 100),
('Moderate', 'Full refund 5 days prior to arrival, except fees.', 5, 100),
('Strict', '50% refund up to 1 week prior to arrival, except fees.', 7, 50),
('Long-term', '50% refund of the first month’s rent up to 30 days prior to check-in, except fees.', 30, 50),
('Super Strict 30 Days', '50% refund up to 30 days before arrival, except fees.', 30, 50),
('Super Strict 60 Days', '50% refund up to 60 days before arrival, except fees.', 60, 50),
('Non-refundable', 'Non-refundable, except fees.', 0, 0),
('Special Event', 'No refunds offered during special event periods, except fees.', 0, 0),
('Seasonal', 'No refunds offered during high season periods, except fees.', 0, 0);

INSERT INTO users (first_name, last_name, email, phone_number, address_id, preferred_currency, password) VALUES
('John', 'Doe', 'john.doe@example.com', '123-456-7890', 38, 'USD', 'password123'),
('Jane', 'Smith', 'jane.smith@example.com', '321-654-9870', 66, 'EUR', 'password321'),
('Alice', 'Johnson', 'alice.johnson@example.com', '231-564-1234', 45, 'GBP', 'aliceSecure123'),
('Bob', 'Brown', 'bob.brown@example.com', '456-789-1230', 42, 'USD', 'bobPassword456'),
('Charlie', 'White', 'charlie.white@example.com', '567-890-1234', 50, 'CAD', 'charliePass567'),
('Diana', 'Black', 'diana.black@example.com', '678-901-2345', 54, 'AUD', 'dianaPass678'),
('Ethan', 'Green', 'ethan.green@example.com', '789-012-3456', 39, 'USD', 'ethanPass789'),
('Fiona', 'Gray', 'fiona.gray@example.com', '890-123-4567', 68, 'EUR', 'fionaPass890'),
('George', 'Blue', 'george.blue@example.com', '901-234-5678',44, 'GBP', 'georgePass901'),
('Hannah', 'Orange', 'hannah.orange@example.com', '012-345-6789', 40, 'USD', 'hannahPass012'),
('Ivan', 'Pink', 'ivan.pink@example.com', '123-456-7890', 63, 'EUR', 'ivanPass123'),
('Julia', 'Silver', 'julia.silver@example.com', '234-567-8901', 49, 'CAD', 'juliaPass234'),
('Kevin', 'Gold', 'kevin.gold@example.com', '345-678-9012', 52, 'AUD', 'kevinPass345'),
('Laura', 'Lime', 'laura.lime@example.com', '456-789-0123', 41, 'USD', 'lauraPass456'),
('Mason', 'Magenta', 'mason.magenta@example.com', '567-890-1234', 72, 'EUR', 'masonPass567'),
('Nora', 'Cyan', 'nora.cyan@example.com', '678-901-2345', 43, 'GBP', 'noraPass678'),
('Oscar', 'Teal', 'oscar.teal@example.com', '789-012-3456', 69, 'USD', 'oscarPass789'),
('Penny', 'Ivory', 'penny.ivory@example.com', '890-123-4567', 48, 'CAD', 'pennyPass890'),
('Quinn', 'Khaki', 'quinn.khaki@example.com', '901-234-5678', 51, 'AUD', 'quinnPass901'),
('Ruby', 'Coral', 'ruby.coral@example.com', '012-345-6789', 60, 'USD', 'rubyPass012'),
('Alex', 'Marshall', 'alex.marshall@example.com', '234-567-8912', 59, 'ZAR', 'alexPass234'),
('Beth', 'Cooper', 'beth.cooper@example.com', '345-678-9013', 60, 'ZAR', 'bethPass345'),
('Cara', 'Wright', 'cara.wright@example.com', '456-789-0124', 61, 'ZAR', 'caraPass456'),
('Dean', 'Taylor', 'dean.taylor@example.com', '567-890-1235', 62, 'ZAR', 'deanPass567'),
('Ella', 'Moore', 'ella.moore@example.com', '678-901-2346', 55, 'JPY', 'ellaPass678'),
('Finn', 'Clark', 'finn.clark@example.com', '789-012-3457', 56, 'JPY', 'finnPass789'),
('Gina', 'Lewis', 'gina.lewis@example.com', '890-123-4568', 57, 'JPY', 'ginaPass890'),
('Hugo', 'Roberts', 'hugo.roberts@example.com', '901-234-5679', 58, 'JPY', 'hugoPass901'),
('Iris', 'James', 'iris.james@example.com', '012-345-6780', 71, 'DKK', 'irisPass012'),
('Joel', 'Allen', 'joel.allen@example.com', '123-456-7891', 72, 'DKK', 'joelPass123'),
('Kara', 'White', 'kara.white@example.com', '234-567-8912', 73, 'DKK', 'karaPass234'),
('Liam', 'Harris', 'liam.harris@example.com', '345-678-9013', 74, 'DKK', 'liamPass345'),
('Mila', 'Martin', 'mila.martin@example.com', '456-789-0124', 63, 'EUR', 'milaPass456'),
('Noah', 'Thompson', 'noah.thompson@example.com', '567-890-1235', 64, 'EUR', 'noahPass567'),
('Ollie', 'Garcia', 'ollie.garcia@example.com', '678-901-2346', 65, 'EUR', 'olliePass678'),
('Pia', 'Martinez', 'pia.martinez@example.com', '789-012-3457', 66, 'EUR', 'piaPass789'),
('Quinn', 'Davis', 'quinn.davis@example.com', '890-123-4568', 67, 'EUR', 'quinnPass890'),
('Rosa', 'Lopez', 'rosa.lopez@example.com', '901-234-5679', 68, 'EUR', 'rosaPass901'),
('Seth', 'Wilson', 'seth.wilson@example.com', '012-345-6780', 69, 'EUR', 'sethPass012'),
('Tina', 'Anderson', 'tina.anderson@example.com', '123-456-7891', 70, 'EUR', 'tinaPass123');

INSERT INTO users (first_name, last_name, email, phone_number, address_id, preferred_currency, password, is_active) VALUES
('Eve', 'Green', 'eve.green@example.com', '654-321-7890', 65, 'EUR', 'evePwd789', 0),
('Sam', 'Violet', 'sam.violet@example.com', '321-654-9870', 46, 'GBP', 'samPwd321', 0);

INSERT INTO guests (user_id, credit_card_details, guest_bio) VALUES
(23, 1234567890123456, 'Enthusiastic traveler from Australia who loves to explore new cultures.'),
(24, 2345678901234567, 'Business professional frequently traveling for conferences and meetings.'),
(25, 3456789012345678, 'Adventurous soul, climbing mountains and diving in seas.'),
(26, 4567890123456789, 'History buff, visiting historical sites around the world.'),
(27, 5678901234567890, 'Foodie, trying out local cuisines wherever I go.'),
(28, 6789012345678901, 'Nature lover, seeking out the most serene landscapes.'),
(29, 7890123456789012, 'Photography enthusiast capturing moments across continents.'),
(30, 8901234567890123, 'Solo traveler, exploring the world one city at a time.'),
(31, 9012345678901234, 'Digital nomad, working from different corners of the globe.'),
(32, 1234567890123456, 'Retired couple enjoying leisurely travels around the world.'),
(33, 2345678901234567, 'Studio artist finding inspiration in various cultures.'),
(34, 3456789012345678, 'Documentary filmmaker creating content on global traditions.'),
(35, 4567890123456789, 'College student on a gap year exploring diverse communities.'),
(36, 5678901234567890, 'Tech enthusiast attending international tech expos and meet-ups.'),
(37, 6789012345678901, 'Healthcare professional attending global seminars and workshops.'),
(38, 7890123456789012, 'Musician on tour, performing in various cities worldwide.'),
(39, 8901234567890123, 'Yoga instructor conducting retreats in tranquil locations.'),
(40, 9012345678901234, 'Journalist covering international events and stories.'),
(41, 1234567890123456, 'Real estate investor scouting properties in emerging markets.'),
(42, 2345678901234567, 'Environmental scientist on field trips to study ecosystems.');

INSERT INTO hosts (user_id, bank_account_details, host_bio) VALUES
(43, 'BankXYZ-0123456789', 'Passionate about providing cozy and welcoming spaces for travelers.'),
(44, 'BankABC-9876543210', 'Offering a luxurious stay in the heart of the city.'),
(45, 'BankDEF-1234509876', 'Loves to host and meet people from different parts of the world.'),
(46, 'BankGHI-5647382910', 'Provides a rustic experience in a country cottage.'),
(47, 'BankJKL-0987654321', 'Hosts a modern apartment with all tech conveniences.'),
(48, 'BankMNO-1234567890', 'Beach house owner, loves surfing and beach volleyball.'),
(49, 'BankPQR-5647382901', 'Mountain lodge owner, great for retreats and nature lovers.'),
(50, 'BankSTU-9078563412', 'City center studio perfect for exploring nightlife.'),
(51, 'BankVWX-3126459780', 'Offers a peaceful stay in a suburban guesthouse.'),
(52, 'BankYZA-7845129630', 'Artistic loft owner, decorated with personal artwork.'),
(53, 'BankBCD-6758493021', 'Family-friendly home with a playground nearby.'),
(54, 'BankEFG-5647382901', 'Pet-friendly apartment with lots of walking trails.'),
(55, 'BankHIJ-4231567890', 'Small town home with a warm, community feel.'),
(56, 'BankKLM-3126459780', 'Historic home with antique furnishings and a large garden.'),
(57, 'BankNOP-9078563412', 'Modern minimalist apartment in a high-rise.'),
(58, 'BankQRS-7845129630', 'Cozy cabin in the woods, great for a quiet getaway.'),
(59, 'BankTUV-6758493021', 'Luxury villa with a private pool and garden.'),
(60, 'BankWXY-5647382910', 'Hostel owner, great for backpackers and solo travelers.'),
(61, 'BankZAB-4231567890', 'Penthouse with panoramic city views.'),
(62, 'BankCDE-3126459780', 'Country house with organic farm and fresh produce.');

INSERT INTO languages (language_code, language_name) VALUES
('EN', 'English'),
('FR', 'French'),
('DE', 'German'),
('NL', 'Dutch'),
('ES', 'Spanish'),
('PT', 'Portuguese'),
('DA', 'Danish'),
('CS', 'Czech'),
('JA', 'Japanese'),
('IT', 'Italian'),
('RU', 'Russian'),
('ZH', 'Chinese'),
('AR', 'Arabic'),
('KO', 'Korean'),
('SV', 'Swedish'),
('NO', 'Norwegian'),
('PL', 'Polish'),
('TR', 'Turkish'),
('FI', 'Finnish'),
('EL', 'Greek');

INSERT INTO languages_spoken (user_id, language_code, language_level) VALUES
(24, 'EN', 'Fluent'),
(24, 'ES', 'Intermediate'),
(25, 'FR', 'Fluent'),
(25, 'DE', 'Beginner'),
(26, 'JA', 'Advanced'),
(27, 'IT', 'Fluent'),
(28, 'RU', 'Intermediate'),
(29, 'PT', 'Fluent'),
(30, 'ZH', 'Beginner'),
(31, 'NL', 'Fluent'),
(32, 'CS', 'Advanced'),
(33, 'KO', 'Intermediate'),
(34, 'SV', 'Fluent'),
(35, 'NO', 'Fluent'),
(36, 'PL', 'Intermediate'),
(37, 'TR', 'Fluent'),
(38, 'FI', 'Beginner'),
(39, 'EL', 'Fluent'),
(40, 'AR', 'Advanced'),
(41, 'DA', 'Intermediate'),
(42, 'EN', 'Fluent'),
(43, 'FR', 'Advanced'),
(44, 'ES', 'Fluent'),
(45, 'DE', 'Intermediate'),
(46, 'JA', 'Fluent'),
(47, 'IT', 'Beginner'),
(48, 'RU', 'Fluent'),
(49, 'PT', 'Intermediate'),
(50, 'ZH', 'Advanced'),
(51, 'NL', 'Beginner'),
(52, 'CS', 'Fluent'),
(53, 'KO', 'Beginner'),
(54, 'SV', 'Advanced'),
(55, 'NO', 'Intermediate'),
(56, 'PL', 'Fluent'),
(57, 'TR', 'Beginner'),
(58, 'FI', 'Fluent'),
(59, 'EL', 'Intermediate'),
(60, 'AR', 'Fluent'),
(61, 'DA', 'Advanced');

INSERT INTO wish_lists (user_id, wish_list_name, description) VALUES
(23, 'Summer Escapes', 'Dream destinations for summer holidays'),
(24, 'Winter Wonderlands', 'Cozy spots for winter breaks'),
(25, 'Adventure Time', 'Exciting places for adventurous souls'),
(26, 'Quiet Retreats', 'Peaceful getaways for relaxation'),
(27, 'Luxury Living', 'Opulent and luxurious destinations'),
(28, 'Budget Travels', 'Affordable vacation spots'),
(29, 'Hidden Gems', 'Undiscovered places around the globe'),
(30, 'Family Fun', 'Family-friendly vacation spots'),
(31, 'Romantic Getaways', 'Perfect spots for a romantic retreat'),
(32, 'Cultural Journeys', 'Rich cultural experiences'),
(33, 'Foodie Adventures', 'Destinations known for amazing food'),
(34, 'Artistic Inspirations', 'Places inspiring creativity and art'),
(35, 'Historical Sites', 'Travel through history with these locations'),
(36, 'Modern Marvels', 'Explore modern architecture and cities'),
(37, 'Nature Lovers', 'Destinations for nature enthusiasts'),
(38, 'Beach Holidays', 'Top beach destinations'),
(39, 'Mountain Escapes', 'Best mountain locations for a getaway'),
(40, 'Sporting Events', 'Travel to major sporting events around the world'),
(41, 'Wellness Retreats', 'Focus on health and wellness'),
(42, 'Shopping Spree', 'The best cities for shopping lovers');

INSERT INTO users_social_profiles (user_id, social_network_name, url, is_verified) VALUES
(43, 'Facebook', 'https://www.facebook.com/user43', 1),
(44, 'Twitter', 'https://www.twitter.com/user44', 0),
(45, 'Instagram', 'https://www.instagram.com/user45', 1),
(46, 'LinkedIn', 'https://www.linkedin.com/in/user46', 0),
(47, 'YouTube', 'https://www.youtube.com/user47', 1),
(48, 'Pinterest', 'https://www.pinterest.com/user48', 0),
(49, 'Snapchat', 'https://www.snapchat.com/add/user49', 1),
(50, 'TikTok', 'https://www.tiktok.com/@user50', 0),
(51, 'Reddit', 'https://www.reddit.com/user/user51', 1),
(52, 'Tumblr', 'https://user52.tumblr.com', 0),
(53, 'Flickr', 'https://www.flickr.com/people/user53', 1),
(54, 'WeChat', 'https://wechat.com/user54', 0),
(55, 'WhatsApp', 'https://wa.me/550', 1),
(56, 'Instagram', 'https://www.instagram.com/user56', 0),
(57, 'Twitter', 'https://www.twitter.com/user57', 1),
(58, 'Facebook', 'https://www.facebook.com/user58', 0),
(59, 'LinkedIn', 'https://www.linkedin.com/in/user59', 1),
(60, 'YouTube', 'https://www.youtube.com/user60', 0),
(61, 'Pinterest', 'https://www.pinterest.com/user61', 1),
(62, 'Snapchat', 'https://www.snapchat.com/add/user62', 0);

INSERT INTO properties (
    user_id, address_id, title, description, bedrooms, beds, bathrooms, private_bathroom,
    type_id, surface, currency_payment, price_per_night, min_stay, checkin_time, cleaning_fee,
    pets_allowed, house_rules_id, cancellation_policy_id, is_active
) VALUES
(43, 38, 'Cozy Cottage', 'A beautiful and cozy cottage.', 2, 3, 1, 1, 1, 50, 'EUR', 85.50, 2, '15:00:00', 15.00, 0, 5, 1, 1),
(44, 39, 'Modern Apartment', 'Stylish apartment in the city center.', 3, 5, 2, 0, 4, 80, 'USD', 120.00, 3, '14:00:00', 20.00, 1, 3, 2, 1),
(45, 40, 'Beach House', 'House right on the beach.', 4, 4, 2, 1, 2, 120, 'AUD', 200.00, 5, '16:00:00', 25.00, 1, 7, 3, 1),
(46, 41, 'Downtown Studio', 'Compact studio in the heart of the city.', 1, 1, 1, 1, 3, 30, 'CAD', 75.00, 1, '15:30:00', 10.00, 0, 9, 4, 1),
(47, 42, 'Country Home', 'Spacious home in a tranquil rural setting.', 5, 5, 3, 0, 5, 150, 'GBP', 150.00, 4, '14:30:00', 30.00, 1, 2, 5, 1),
(48, 43, 'Suburban Bungalow', 'Quiet, well-connected location.', 3, 3, 2, 0, 6, 100, 'CHF', 90.00, 2, '16:00:00', 20.00, 0, 4, 6, 1),
(49, 44, 'Loft', 'Modern loft with industrial charm.', 2, 2, 1, 1, 7, 70, 'JPY', 11000.00, 3, '15:00:00', 15.00, 1, 1, 7, 1),
(50, 45, 'Villa', 'Luxurious villa with private pool.', 4, 6, 4, 1, 8, 200, 'EUR', 350.00, 7, '14:00:00', 50.00, 0, 6, 8, 1),
(51, 46, 'Penthouse', 'Top floor with stunning views.', 3, 4, 3, 1, 9, 110, 'USD', 250.00, 2, '16:30:00', 40.00, 1, 8, 9, 1),
(52, 47, 'Mansion', 'A grand mansion with exquisite gardens.', 6, 8, 5, 0, 10, 300, 'DKK', 2300.00, 6, '14:00:00', 60.00, 0, 3, 1, 1),
(53, 48, 'Townhouse', 'Elegant townhouse in a prestigious area.', 4, 5, 2, 0, 11, 90, 'GBP', 180.00, 3, '15:00:00', 25.00, 1, 11, 2, 1),
(54, 49, 'Farmhouse', 'Rustic farmhouse with lots of charm.', 4, 4, 2, 1, 12, 140, 'AUD', 130.00, 4, '15:30:00', 20.00, 0, 5, 3, 1),
(55, 50, 'Apartment', 'Convenient and affordable city living.', 2, 2, 1, 0, 13, 60, 'CAD', 95.00, 2, '16:00:00', 12.00, 1, 10, 4, 1),
(56, 51, 'Duplex', 'Spacious duplex near downtown.', 3, 3, 2, 1, 14, 85, 'CHF', 140.00, 3, '14:30:00', 18.00, 0, 12, 5, 1),
(57, 52, 'Cabin', 'Cozy cabin in the mountains.', 2, 2, 1, 1, 15, 45, 'EUR', 100.00, 1, '15:00:00', 20.00, 1, 14, 6, 1),
(58, 53, 'Mobile Home', 'Comfortable mobile home in a nice park.', 1, 1, 1, 0, 16, 25, 'JPY', 8000.00, 1, '16:30:00', 5.00, 0, 17, 7, 1),
(59, 54, 'Cottage', 'Charming cottage with garden access.', 3, 3, 2, 0, 17, 70, 'GBP', 110.00, 5, '14:30:00', 22.00, 1, 15, 8, 1),
(60, 55, 'Studio', 'Ideal for singles or young couples.', 1, 1, 1, 1, 18, 35, 'DKK', 750.00, 2, '15:00:00', 8.00, 0, 4, 9, 1),
(61, 56, 'Condo', 'Modern condo with all amenities.', 2, 2, 1, 1, 19, 65, 'USD', 130.00, 3, '15:30:00', 15.00, 1, 3, 1, 1),
(62, 57, 'Traditional Home', 'Beautifully furnished in a quiet neighborhood.', 4, 4, 3, 0, 1, 150, 'KRW', 160000.00, 4, '16:00:00', 35.00, 1, 8, 2, 1);

INSERT INTO property_amenities (amenity_id, property_id, comment) VALUES
(1, 1, ''),
(2, 1, ''),
(3, 1, ''),
(4, 1, ''),
(5, 1, ''),
(1, 2, 'Fast internet for business travelers.'),
(6, 2, ''),
(7, 2, ''),
(8, 2, ''),
(9, 2, ''),
(1, 3, 'Wi-Fi available in all areas.'),
(3, 3, ''),
(10, 3, ''),
(11, 3, ''),
(12, 3, ''),
(2, 4, 'Individual A/C in every room.'),
(4, 4, ''),
(13, 4, ''),
(14, 4, 'Pets are welcome.'),
(1, 5, ''),
(5, 5, 'Washer included for convenience.'),
(7, 5, ''),
(17, 5, ''),
(3, 6, ''),
(6, 6, 'Dryer available for guests.'),
(18, 6, 'All essentials provided.'),
(19, 6, ''),
(20, 6, ''),
(1, 7, 'Complimentary Wi-Fi access.'),
(8, 7, 'Private bathroom facilities.'),
(9, 7, ''),
(10, 7, 'Ample parking space.'),
(11, 7, 'Gym for health enthusiasts.'),
(12, 1, ''),
(13, 2, 'Enjoy the view from the balcony.'),
(14, 3, 'Relax in the hot tub.'),
(15, 4, 'Safety first with smoke alarms.'),
(16, 5, 'First aid kit available.');

INSERT INTO property_rules (property_id, house_rule_id) VALUES
(1, 1),
(1, 2),
(1, 3),
(1, 4),
(1, 5),
(2, 1),
(2, 6),
(2, 7),
(2, 8),
(2, 9),
(3, 2),
(3, 10),
(3, 11),
(3, 12),
(3, 13),
(4, 3),
(4, 14),
(4, 15),
(4, 16),
(4, 5),
(5, 1),
(5, 6),
(5, 17),
(5, 18),
(5, 19),
(6, 2),
(6, 7),
(6, 10),
(6, 14),
(6, 17),
(7, 3),
(7, 8),
(7, 11),
(7, 15),
(7, 18),
(8, 4),
(8, 9),
(8, 12),
(8, 16),
(8, 19),
(9, 5),
(9, 6),
(10, 7),
(10, 8),
(11, 9),
(11, 10),
(12, 11),
(12, 12),
(13, 13),
(13, 14),
(14, 15),
(14, 16),
(15, 17),
(15, 18),
(16, 19),
(16, 1),
(17, 2),
(17, 3),
(18, 4),
(18, 5),
(19, 6),
(19, 7);

INSERT INTO property_availability (property_id, starts_date, end_date, reason) VALUES
(1, '2024-05-04', '2024-05-07', 'Booked'),
(1, '2024-06-15', '2024-06-18', 'Booked'),
(1, '2024-07-08', '2024-07-14', 'Maintenance'),
(1, '2024-08-01', '2024-08-05', 'Booked'),
(1, '2024-09-12', '2024-09-18', 'Booked'),
(1, '2024-11-20', '2024-11-26', 'Renovation'),
(2, '2024-05-10', '2024-05-12', 'Booked'),
(2, '2024-06-22', '2024-06-28', 'Booked'),
(2, '2024-07-15', '2024-07-19', 'Private Event'),
(2, '2024-08-07', '2024-08-13', 'Booked'),
(2, '2024-09-22', '2024-09-28', 'Booked'),
(2, '2024-11-29', '2024-12-05', 'Cleaning'),
(3, '2024-05-16', '2024-05-22', 'Booked'),
(3, '2024-06-30', '2024-07-05', 'Booked'),
(3, '2024-07-20', '2024-07-26', 'Owner Use'),
(3, '2024-08-15', '2024-08-21', 'Booked'),
(3, '2024-09-30', '2024-10-05', 'Booked'),
(3, '2024-12-10', '2024-12-16', 'Booked'),
(4, '2024-05-23', '2024-05-29', 'Booked'),
(4, '2024-07-07', '2024-07-13', 'Booked'),
(4, '2024-08-23', '2024-08-29', 'Booked'),
(4, '2024-09-07', '2024-09-13', 'Booked'),
(4, '2024-10-15', '2024-10-21', 'Seasonal Closure'),
(4, '2024-11-02', '2024-11-08', 'Booked'),
(5, '2024-05-30', '2024-06-05', 'Booked'),
(5, '2024-07-14', '2024-07-20', 'Booked'),
(5, '2024-08-30', '2024-09-05', 'Booked'),
(5, '2024-09-14', '2024-09-20', 'Booked'),
(5, '2024-10-22', '2024-10-28', 'Booked'),
(5, '2024-11-09', '2024-11-15', 'Upgrades'),
(6, '2024-06-06', '2024-06-12', 'Booked'),
(6, '2024-07-21', '2024-07-27', 'Booked'),
(6, '2024-09-06', '2024-09-12', 'Booked'),
(6, '2024-09-21', '2024-09-27', 'Booked'),
(6, '2024-10-29', '2024-11-04', 'Booked'),
(6, '2024-11-16', '2024-11-22', 'Pest Control'),
(7, '2024-06-13', '2024-06-19', 'Booked'),
(7, '2024-07-28', '2024-08-03', 'Booked'),
(7, '2024-09-01', '2024-09-07', 'Booked'),
(7, '2024-09-28', '2024-10-04', 'Booked'),
(7, '2024-11-05', '2024-11-11', 'Booked'),
(7, '2024-11-23', '2024-11-29', 'Filming'),
(8, '2024-05-01', '2024-05-05', 'Booked'),
(8, '2024-06-20', '2024-06-25', 'Booked'),
(8, '2024-07-29', '2024-08-04', 'Booked'),
(8, '2024-08-10', '2024-08-16', 'Booked'),
(8, '2024-09-08', '2024-09-14', 'Booked'),
(8, '2024-10-06', '2024-10-12', 'Construction'),
(9, '2024-05-06', '2024-05-10', 'Booked'),
(9, '2024-06-26', '2024-07-01', 'Booked'),
(9, '2024-08-05', '2024-08-11', 'Booked'),
(9, '2024-08-17', '2024-08-23', 'Booked'),
(9, '2024-09-15', '2024-09-21', 'Booked'),
(9, '2024-10-13', '2024-10-19', 'Local Event');

INSERT INTO wish_list_items (wish_list_id, property_id) VALUES
(1, 1),
(1, 2),
(1, 3),
(2, 4),
(2, 5),
(2, 6),
(2, 7),
(3, 8),
(3, 9),
(3, 10),
(4, 11),
(4, 12),
(4, 13),
(5, 14),
(5, 15),
(5, 16),
(5, 17),
(6, 18),
(6, 19),
(6, 1),
(7, 2),
(7, 3),
(7, 4),
(8, 5),
(8, 6),
(8, 7),
(9, 8),
(9, 9),
(9, 10),
(10, 11),
(10, 12),
(10, 13),
(11, 14),
(11, 15),
(11, 16),
(12, 17),
(12, 18),
(12, 19),
(13, 1),
(13, 2),
(13, 3),
(14, 4),
(14, 5),
(14, 6),
(15, 7),
(15, 8),
(15, 9),
(16, 10),
(16, 11),
(16, 12),
(17, 13),
(17, 14),
(17, 15),
(18, 16),
(18, 17),
(18, 18),
(19, 19),
(19, 1),
(19, 2);

INSERT INTO bookings (property_id, user_id, booking_date, checkin_date, checkout_date, total_price, status) VALUES
(1, 23, '2024-05-03', '2024-05-04', '2024-05-07', 300.00, 'pending'),
(1, 24, '2024-06-14', '2024-06-15', '2024-06-18', 450.00, 'pending'),
(1, 25, '2024-08-01', '2024-08-01', '2024-08-05', 500.00, 'pending'),
(1, 26, '2024-09-11', '2024-09-12', '2024-09-18', 600.00, 'pending'),
(2, 27, '2024-05-09', '2024-05-10', '2024-05-12', 200.00, 'pending'),
(2, 28, '2024-06-21', '2024-06-22', '2024-06-28', 700.00, 'pending'),
(2, 29, '2024-08-06', '2024-08-07', '2024-08-13', 650.00, 'pending'),
(2, 30, '2024-09-21', '2024-09-22', '2024-09-28', 750.00, 'pending'),
(3, 31, '2024-05-15', '2024-05-16', '2024-05-22', 550.00, 'pending'),
(3, 32, '2024-06-29', '2024-06-30', '2024-07-05', 500.00, 'pending'),
(3, 33, '2024-08-14', '2024-08-15', '2024-08-21', 600.00, 'pending'),
(3, 34, '2024-09-29', '2024-09-30', '2024-10-05', 550.00, 'pending'),
(4, 35, '2024-05-22', '2024-05-23', '2024-05-29', 400.00, 'pending'),
(4, 36, '2024-07-06', '2024-07-07', '2024-07-13', 450.00, 'pending'),
(4, 37, '2024-08-22', '2024-08-23', '2024-08-29', 475.00, 'pending'),
(4, 38, '2024-09-06', '2024-09-07', '2024-09-13', 425.00, 'pending'),
(5, 39, '2024-05-29', '2024-05-30', '2024-06-05', 350.00, 'completed'),
(6, 40, '2024-06-05', '2024-06-06', '2024-06-12', 600.00, 'completed'),
(7, 41, '2024-06-12', '2024-06-13', '2024-06-19', 550.00, 'completed'),
(8, 42, '2024-04-30', '2024-05-01', '2024-05-05', 250.00, 'cancelled');
(1, 43, '2023-02-01', '2023-02-02', '2023-02-05', 320.00, 'completed'),
(1, 44, '2023-02-10', '2023-02-11', '2023-02-14', 300.00, 'completed'),
(1, 45, '2023-02-18', '2023-02-19', '2023-02-22', 310.00, 'completed'),
(1, 46, '2023-03-01', '2023-03-02', '2023-03-05', 330.00, 'completed'),
(2, 47, '2023-03-10', '2023-03-11', '2023-03-14', 220.00, 'completed'),
(2, 48, '2023-03-20', '2023-03-21', '2023-03-24', 210.00, 'completed'),
(2, 49, '2023-04-01', '2023-04-02', '2023-04-05', 200.00, 'completed'),
(2, 50, '2023-04-10', '2023-04-11', '2023-04-14', 230.00, 'completed'),
(3, 51, '2023-04-20', '2023-04-21', '2023-04-24', 250.00, 'completed'),
(3, 52, '2023-05-01', '2023-05-02', '2023-05-05', 270.00, 'completed'),
(3, 53, '2023-05-10', '2023-05-11', '2023-05-14', 260.00, 'completed'),
(3, 54, '2023-05-20', '2023-05-21', '2023-05-24', 280.00, 'completed'),
(4, 55, '2023-06-01', '2023-06-02', '2023-06-05', 350.00, 'completed'),
(4, 56, '2023-06-10', '2023-06-11', '2023-06-14', 360.00, 'completed'),
(4, 57, '2023-06-20', '2023-06-21', '2023-06-24', 340.00, 'completed'),
(4, 58, '2023-07-01', '2023-07-02', '2023-07-05', 370.00, 'completed'),
(5, 59, '2023-07-10', '2023-07-11', '2023-07-14', 320.00, 'completed'),
(6, 60, '2023-07-20', '2023-07-21', '2023-07-24', 310.00, 'completed'),
(7, 61, '2023-08-01', '2023-08-02', '2023-08-05', 300.00, 'completed'),
(8, 62, '2023-08-10', '2023-08-11', '2023-08-14', 290.00, 'completed');

INSERT INTO financial_transactions (user_id, booking_id, transaction_type, amount, currency, status) VALUES
(43, 1, 'Payment', 320.00, 'USD', 'Paid to Host'),
(44, 2, 'Payment', 300.00, 'CAD', 'Paid to Host'),
(45, 3, 'Payment', 310.00, 'USD', 'Paid to Host'),
(46, 4, 'Payment', 330.00, 'USD', 'Paid to Host'),
(47, 5, 'Payment', 220.00, 'USD', 'Paid to Host'),
(48, 6, 'Payment', 210.00, 'USD', 'Paid to Host'),
(49, 7, 'Payment', 200.00, 'USD', 'Paid to Host'),
(50, 8, 'Payment', 230.00, 'USD', 'Paid to Host'),
(51, 9, 'Payment', 250.00, 'GBP', 'Paid to Host'),
(52, 10, 'Payment', 270.00, 'USD', 'Paid to Host'),
(53, 11, 'Payment', 260.00, 'EUR', 'Paid to Host'),
(54, 12, 'Payment', 280.00, 'USD', 'Paid to Host'),
(55, 13, 'Payment', 350.00, 'USD', 'Paid to Host'),
(56, 14, 'Payment', 360.00, 'USD', 'Paid to Host'),
(57, 15, 'Payment', 340.00, 'USD', 'Paid to Host'),
(58, 16, 'Payment', 370.00, 'EUR', 'Pending Payment from Guest'),
(59, 17, 'Payment', 320.00, 'USD', 'Pending Payment from Guest'),
(60, 18, 'Payment', 310.00, 'USD', 'Pending Payment from Guest'),
(61, 19, 'Hold', 300.00, 'EUR', 'Amount Blocked'),
(62, 20, 'Hold', 290.00, 'USD', 'Amount Blocked');

INSERT INTO reviews (booking_id, reviewer_id, reviewee_id, rating, review_text) VALUES
(21, 23, 43, 9, 'Fantastic experience, highly recommended!'),
(22, 24, 44, 8, 'Very clean and comfortable, great host.'),
(23, 25, 45, 10, 'Perfect stay, exceeded all expectations!'),
(24, 26, 46, 9, 'Wonderful location and amenities.'),
(25, 27, 47, 8, 'Host was very accommodating, lovely place.'),
(26, 28, 48, 10, 'Absolutely loved it here, will return!'),
(27, 29, 49, 9, 'Quiet, clean, and just as described.'),
(28, 30, 50, 8, 'Very pleasant stay, host was outstanding.'),
(29, 31, 51, 9, 'Great experience, everything was perfect.'),
(30, 32, 52, 10, 'Could not have asked for a better stay!'),
(31, 33, 53, 6, 'Decent place, but had some noisy neighbors.'),
(32, 34, 54, 5, 'Average stay, you get what you pay for.'),
(33, 35, 55, 7, 'Pretty good overall, but room for improvement.'),
(34, 36, 56, 3, 'Disappointing service, unclean bathroom.'),
(35, 37, 57, 4, 'Expectations not met, photos were misleading.'),
(36, 38, 58, 5, 'Mediocre service, inconvenient location.'),
(37, 39, 59, 2, 'Had issues with heating, very uncomfortable.'),
(38, 40, 60, 6, 'Okay for short stays, but not very welcoming.'),
(39, 41, 61, 4, 'Not as advertised, host was hard to reach.'),
(40, 42, 62, 1, 'Worst experience ever, very rude host.');

INSERT INTO booking_messages (sender_id, recipient_id, booking_id, message, sent_at) VALUES
(39, 59, 37, 'Hi, I wanted to report that the heating isn''t working. It’s quite cold in the apartment.', '2023-07-11 10:00:00'),
(59, 39, 37, 'Hello, I’m sorry to hear that. Have you tried adjusting the thermostat?', '2023-07-11 10:15:00'),
(39, 59, 37, 'Yes, I’ve tried that already. It seems like the system is not turning on at all.', '2023-07-11 10:30:00'),
(59, 39, 37, 'I see. Unfortunately, I’m not in the area currently. It might be something simple, but I can’t check on it until next week.', '2023-07-11 11:00:00'),
(39, 59, 37, 'That’s quite inconvenient as it’s really cold. Is there no one else who can check this issue?', '2023-07-11 11:05:00'),
(59, 39, 37, 'I don’t have anyone nearby to assist at the moment. Maybe you can get a portable heater for now?', '2023-07-11 11:30:00'),
(39, 59, 37, 'That’s not really a solution, I’m expecting the amenities included to be functioning as advertised.', '2023-07-11 11:45:00'),
(59, 39, 37, 'I understand, but there’s little I can do from here right now.', '2023-07-13 12:15:00'),
(39, 59, 37, 'Our stay in your property was horrible because of the cold. This is quite unacceptable. I will be contacting support to complain and request a refund.',
 '2023-07-15 14:00:00')
(28, 38, 26, 'Hello, I have just arrived and the place looks great!', '2023-02-01 15:00:00'),
(38, 28, 26, 'Thank you for letting me know! Hope you have a wonderful stay.', '2023-02-01 15:10:00'),
(28, 38, 26, 'Could you recommend any good restaurants nearby?', '2023-02-01 18:30:00'),
(38, 28, 26, 'Sure, I would recommend trying out The Seaside Grill. It’s just a few blocks away!', '2023-02-01 18:45:00'),
(29, 39, 27, 'Hi, I’m planning to check in around 3 PM, is that okay?', '2023-02-05 09:00:00'),
(39, 29, 27, 'Yes, that works perfectly. I will see you then!', '2023-02-05 09:15:00'),
(29, 39, 27, 'Thank you! Also, is there parking available on the premises?', '2023-02-05 10:00:00'),
(39, 29, 27, 'There is free parking available for one vehicle. Let me know if you need more.', '2023-02-05 10:05:00'),
(30, 40, 28, 'Good evening, could you confirm the Wi-Fi details?', '2023-02-10 20:00:00'),
(40, 30, 28, 'Good evening! Yes, the Wi-Fi network is "Guests_40" and the password is "Welcome1234".', '2023-02-10 20:10:00'),
(30, 40, 28, 'Thanks! One more thing, is there a hairdryer in the bathroom?', '2023-02-10 21:00:00'),
(40, 30, 28, 'Yes, you will find a hairdryer in the top drawer of the bathroom cabinet.', '2023-02-10 21:05:00');

INSERT INTO support_ticket
(booking_id, user_id, subject, message, created_at, closed_at, status, resolution)
VALUES
(37, 39, 'Heating Issue in Accommodation', 'The heating system in the accommodation is not working, and it is very cold. I have contacted the host, but the issue has not been resolved.', '2023-07-15 08:00:00',
 '2023-07-22 15:00:00', 'closed', 'The host recognized the issue. The guest was given a 50% refund as compensation for the inconvenience.');


INSERT INTO support_ticket
(booking_id, user_id, subject, message, created_at, closed_at, status, resolution)
VALUES
(1, 23, 'Request for Early Check-In', 'Can I check in at 10 AM instead of 2 PM?', '2023-02-01 12:00:00', NULL, 'pending customer reply', NULL),
(3, 24, 'Lost Item', 'I think I left my watch in the bedroom. Could you please check?', '2023-02-04 14:00:00', NULL, 'open', NULL),
(5, 26, 'Payment Issue', 'I was charged twice for my booking. Can you please look into this?', '2023-02-07 16:00:00', '2023-02-14 12:00:00', 'closed', 'The duplicate charge was a system error and has been refunded.'),
(7, 28, 'Extra Guest Query', 'Is it possible to bring an extra guest?', '2023-02-10 10:00:00', NULL, 'open', NULL),
(9, 30, 'Wifi Password Incorrect', 'The Wi-Fi password provided is not working.', '2023-02-12 09:00:00', '2023-02-12 15:00:00', 'closed', 'The correct Wi-Fi password was provided to the guest.'),
(11, 32, 'Broken Air Conditioner', 'The air conditioning unit is not working properly.', '2023-02-15 11:00:00', NULL, 'working', NULL),
(13, 34, 'Request for Property Review Removal', 'A recent review seems unfair and I would like it reviewed by your team.', '2023-02-18 13:00:00', NULL, 'pending customer reply', NULL),
(15, 36, 'No Hot Water', 'There is no hot water in the shower.', '2023-02-20 08:00:00', '2023-02-23 14:00:00', 'closed', 'The issue was resolved by repairing the hot water heater.'),
(17, 38, 'Inaccurate Listing Description', 'The listing description does not match the actual amenities provided.', '2023-02-22 16:00:00', NULL, 'open', NULL),
(19, 40, 'Late Check-Out Request', 'Can I check out at 3 PM instead of 11 AM?', '2023-02-25 17:00:00', NULL, 'open', NULL),
(21, 42, 'Missing Booking Confirmation', 'I have not received a booking confirmation email.', '2023-02-28 13:00:00', '2023-03-01 12:00:00', 'closed', 'Confirmation email was resent to the guest.'),
(23, 44, 'Complaint About a Neighbor', 'The neighbor is very noisy. What can be done about this?', '2023-03-02 19:00:00', NULL, 'working', NULL),
(25, 46, 'Request for Cleaning Service', 'Can the place be cleaned tomorrow?', '2023-03-05 15:00:00', NULL, 'pending customer reply', NULL),
(27, 48, 'Parking Space Issue', 'The designated parking space is occupied by someone else.', '2023-03-08 20:00:00', NULL, 'working', NULL),
(29, 50, 'Unresponsive Host', 'The host is not responding to my messages.', '2023-03-10 18:00:00', NULL, 'open', NULL),
(31, 52, 'Pet Policy Clarification', 'Can you confirm if pets are allowed?', '2023-03-12 11:00:00', '2023-03-15 16:00:00', 'closed', 'Pets are allowed as per the listing details.'),
(33, 54, 'Refund Request for Cancellation', 'I had to cancel due to an emergency. Can I get a refund?', '2023-03-17 14:00:00', NULL, 'pending customer reply', NULL),
(35, 56, 'Report of Damage', 'There is some damage to the furniture that I wanted to report.', '2023-03-20 09:00:00', NULL, 'working', NULL),
(40, 60, 'Feedback on Stay', 'I had a great experience,and would like to leave a review.', '2023-03-23 12:00:00', '2023-03-24 10:00:00', 'closed', 'Feedback noted and appreciated.');
